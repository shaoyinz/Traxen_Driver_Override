# %%
import sys
sys.path.insert(0, "..")

from scripts.data_loader import config, read_nov_data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 4
#       1 import sys
#       2 sys.path.insert(0, "..")
# ----> 4 from scripts.data_loader import config, read_nov_data
#
# File ~/umsi/SI699/Traxen_Driver_Override/jupyter_notebooks/../scripts/data_loader.py:27
#      24 import polars as pl
#      25 import py7zr
# ---> 27 from config import COLS
#      30 # ---------------------------------------------------------------------------
#      31 # Step 1 – Archive Extraction + Lazy Scan
#      32 # ---------------------------------------------------------------------------
#      34 def read_nov_data(
#      35     data_dir: str = "data/nov_data",
#      36     truck_ids: list[str] | None = None,
#      37 ) -> dict[str, pl.LazyFrame]:
#
# ModuleNotFoundError: No module named 'config'

# %%
truck_lfs = read_nov_data(data_dir="../data/nov_data")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 truck_lfs = read_nov_data(data_dir="../data/nov_data")
#
# File ~/umsi/SI699/Traxen_Driver_Override/jupyter_notebooks/../scripts/read_data.py:22, in read_nov_data(data_dir, truck_ids)
#      20 data_dir = Path(data_dir)
#      21 cache_dir = data_dir / "_parquet_cache"
# ---> 22 cache_dir.mkdir(exist_ok=True)
#      23 truck_lfs = {}
#      25 for archive_path in sorted(data_dir.glob("*.7z")):
#
# File ~/.local/share/uv/python/cpython-3.13.11-macos-aarch64-none/lib/python3.13/pathlib/_local.py:722, in Path.mkdir(self, mode, parents, exist_ok)
#     718 """
#     719 Create a new directory at this given path.
#     720 """
#     721 try:
# --> 722     os.mkdir(self, mode)
#     723 except FileNotFoundError:
#     724     if not parents or self.parent == self:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/nov_data/_parquet_cache'

# %%
import polars as pl

lf = truck_lfs["5FT0192"]

# Build a proper Datetime from the Date (filename) + Timestamp (seconds since midnight)
# Find continuous timeframes where iQCMode is any of 2, 3, 4, or 5.
# Switching between these values does NOT break the segment.
# A new segment starts only when the gap between consecutive active rows > 1s.
active_segments = (
    lf.select("Date", "Timestamp", "iQC1.iQCMode")
    .drop_nulls()
    .filter(pl.col("iQC1.iQCMode").is_in([2, 3, 4, 5]))
    .with_columns(
        (
            pl.col("Date").str.to_date("%Y-%m-%d").dt.timestamp("ms")
            + (pl.col("Timestamp") * 1_000).cast(pl.Int64)
        )
        .cast(pl.Datetime("ms"))
        .alias("Datetime"),
    )
    .sort("Datetime")
    .with_columns(
        (pl.col("Datetime").diff().dt.total_seconds() > 1.0)
        .fill_null(True)
        .cum_sum()
        .alias("segment_id"),
    )
    .group_by("segment_id")
    .agg(
        pl.col("Datetime").min().alias("start"),
        pl.col("Datetime").max().alias("end"),
        pl.col("Datetime").count().alias("row_count"),
        pl.col("iQC1.iQCMode").unique().sort().alias("modes_seen"),
    )
    .with_columns(
        (pl.col("end") - pl.col("start")).alias("duration"),
    )
    .sort("start")
    .drop("segment_id")
    .collect()
)

print(f"{len(active_segments)} continuous timeframes")
active_segments
